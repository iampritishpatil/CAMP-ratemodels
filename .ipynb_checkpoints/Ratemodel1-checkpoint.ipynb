# %%
# %matplotlib inline
import math
from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt

# %%
global c1,c2,c3,c4,ke,ki,r,tau_e,tau_i,a,theta,P,Q
c1=12
c2=4
c3=13
c4=11
a=1
theta=1
ke=1
ki=1
re=1
ri=1
r=1
P=0
Q=0

def eqs(y,t):
    E,I=y
    dEdt =  -E + sigm(c1*E - c2*I + P)*(ke-re*E)
    dIdt =  -I + sigm(c3*E - c4*I + Q)*(ki-ri*I)
    dydt=[dEdt,dIdt]
    return dydt

# %%
sigm = lambda x : 1 / (1 + math.exp(-1*a*(x-theta))) - 1 / (1 + math.exp(-1*a*(theta)))

# %%
y0=[0,0]
t = np.linspace(0, 10, 1001)
sol = odeint(eqs, y0, t)

# %%
import matplotlib.pyplot as plt
plt.plot(t, sol[:, 0], 'b', label='E')
plt.plot(t, sol[:, 1], 'g', label='I')
plt.legend(loc='best')
plt.xlabel('t')
plt.grid()
plt.show()

# %%
# The Wilson-Cowan Model
# Set the fixed parameters
global a,b,c,d,q,p
a=16
b=12
c=16
d=5
q=-4
p=-5
# 3
# the wilson-cowan equations


def eqs(y,t):
    E,I=y
    # u’=-u+f(a*u-b*v+p)
    # v’=-v+f(c*u-d*v+q)

    E_prime=-E+f(a*E-b*I+p(t))
    I_prime=-I+f(c*E-d*I+q(t))
    dydt=[E_prime,I_prime]
    return dydt


f= lambda x : 1/(1+math.exp(-x))
# Set the adjustable parameter.
p = lambda t : np.random.random(1)
q = lambda t : np.random.random(1)

y0=[0.2,0.4]
t = np.linspace(0, 10, 1001)
sol = odeint(eqs, y0, t)

import matplotlib.pyplot as plt
plt.plot(t, sol[:, 0], 'b', label='E')
plt.plot(t, sol[:, 1], 'g', label='I')
plt.legend(loc='best')
plt.xlabel('t')
plt.grid()
plt.show()

# %% [markdown]
# ## Building upto a network model
#
# We first start with a simple ratemodel of a neuron.
#
# $ \tau \dot{w} = -w + i $ where $i$ is input

# %%
def eqs(y,t):
    dydt=(-y + I(t))/tau()
    return dydt
tau = lambda : 10
I = lambda t : t*0.1
# I = lambda t : 0.5*(t>5 and t<7)
# I = lambda t : np.sin(t)*0.1


y0=[0.2]
t = np.linspace(0, 20, 1001)
sol = odeint(eqs, y0, t)
plt.style.use('ggplot')
plt.plot(t, sol[:, 0], 'b')
# plt.legend(loc='best')
plt.xlabel('t')
plt.grid()
plt.show()

# %% [markdown]
# Lets make a neuron with an autoapse, a synapse with itself
#
# $ \tau \dot{y} = -y + Wy + i $

# %%
def eqs(y,t):
    dydt=(-y + I(t) + W() * y)/tau()
    return dydt
tau = lambda : 2
W = lambda : 0.1

# I = lambda t : 0.1
# I = lambda t : 0.5*(t>5 and t<7)
I = lambda t : np.sin(t)*0.1


y0=[0.2]
t = np.linspace(0, 20, 1001)
sol = odeint(eqs, y0, t)
plt.style.use('ggplot')
plt.plot(t, sol[:, 0], 'b')
plt.plot(t, map(I,t), 'r')
# plt.legend(loc='best')
plt.xlabel('t')
plt.grid()
plt.show()

# %% [markdown]
# ## Mutually Inhibitory Pair
#
# $ \tau \dot{x1} = -\bar{x1} - \beta x2 +b  $
#
# $ \tau \dot{x2} = -\bar{x2} - \beta x1 +b  $

# %%
def eqs(y,t):
    tau=np.array([2,4])
    b=np.array([0.2,0.1])
    beta=0.5
    W=np.array([[0, -beta],[-beta,0]])
    dydt=(-y +  y.dot(W) + b)/tau
    return dydt


y0=np.array([0.1,0.3])
t = np.linspace(0, 20, 1001)
sol = odeint(eqs, y0, t)
plt.style.use('ggplot')
plt.subplot(211)
plt.plot(t, sol[:, 0], 'b')
plt.plot(t, sol[:, 1], 'g')
plt.subplot(212)
plt.plot(t, sol[:, 0] + sol[:, 1], 'b')
plt.plot(t, sol[:, 0] - sol[:, 1], 'g')
plt.show()

# %%
np.array(y0).dot(np.array(W()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-39a7794d3115> in <module>()
# ----> 1 np.array(y0).dot(np.array(W()))
#
# ValueError: shapes (1,) and (2,2) not aligned: 1 (dim 0) != 2 (dim 0)

# %% [markdown]
# ## Network
# $ \tau \dot{\bar{r}} = -\bar{r} + W\bar{r} + \bar{i} $

# %% [markdown]
# ## Misha's paper

# %%
def eqs(y,t):
    tau_e=20.0
    tau_i=10.0
    Jee=40.0
    Jei=25.0
    Jie=30.0
    Jii=15.0
    E,I = y
    dEdt = (-E+g_e(Jee *E - Jei * I + e(t)))/tau_e
    dIdt = (-I+g_i(Jie *E - Jii * I + i(t)))/tau_i
    dydt=[dEdt, dIdt]
    return dydt

T=120

def e(t):
    return 0.1
def i(t):
    return 0.1*np.sin(2*np.pi*t/T)
def g_e(x):
    if x>0:
        return np.tanh(x)
    return 0
def g_i(x):
    if x>0:
        return np.tanh(x)
    return 0


y0=np.array([0.,0.])
tmax=0.5
t = np.linspace(0, tmax*1000, tmax*1000+1)
sol = odeint(eqs, y0, t)
plt.style.use('ggplot')
f, axarr = plt.subplots(2, sharex=True)
f.figsize=[20,10]
axarr[0].plot(t, sol[:, 0], 'b')
axarr[0].plot(t, sol[:, 1], 'g')
axarr[1].plot(t, i(t)*0.1, 'r')

# plt.subplot(211)

# plt.plot(t, sol[:, 0], 'b')
# plt.plot(t, sol[:, 1], 'g')
# plt.subplot(212)
# plt.plot(t, i(t)*0.1, 'r')
# plt.plot(t, sol[:, 0] + sol[:, 1], 'b')
# plt.plot(t, sol[:, 0] - sol[:, 1], 'g')
# plt.show()

# %%
np.linspace(0,10,21)
# Out:
# array([  0. ,   0.5,   1. ,   1.5,   2. ,   2.5,   3. ,   3.5,   4. ,
#          4.5,   5. ,   5.5,   6. ,   6.5,   7. ,   7.5,   8. ,   8.5,
#          9. ,   9.5,  10. ])
